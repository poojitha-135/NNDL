# %%
import numpy as np
x = np.array([0.5, 0.4, 0.1])
w = np.array([[0.2, 0.6], [0.3,0.1], [0.5,0.4]])
b = np.array([0.01,0.02])
z = np.dot(x,w)+b
print("output",z)
def sigmoid(x):
  return 1/(1+np.exp(-x))
a = sigmoid(z)
print("activated output:",a)
w2 = np.array([[0.1], [0.2]])
b2 = np.array([0.3])
z2 = np.dot(a,w2)+b2
a2 = sigmoid(z2)
print("final output:",a2)
y=1
loss=(y-a2)**2
print("loss:",loss)
lr=0.1
dloss_da2 = -2*(y-a2)
da2_dz2 = a2 *(1-a2)
dz2_dw2 = a
grad_w2 = dloss_da2*da2_dz2*dz2_dw2
w2 = w2 -lr* grad_w2.reshape(2,1)
print("updtaed w2:",w2)
# Out:
# output [0.28 0.4 ]
# activated output: [0.56954622 0.59868766]
# final output: [0.61696647]
# loss: [0.14671468]
# updtaed w2: [[0.11031084]
#  [0.21083841]]
